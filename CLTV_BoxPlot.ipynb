# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("CLTVFinalSheet.csv", encoding="unicode_escape")
print("Total number of transactions happened in the given period: "+ str(data.shape[0]))
data.head(5)
# Out:
# Total number of transactions happened in the given period: 15908
#                    Name  Sum of Gross Margin  Sum of  Product Discounted %  \
# 0  Priyanka  Khandelwal            -4504.690                      0.000000
# 1        Protima Tiwary              153.000                      0.499371
# 2         arjita grover             3025.979                      4.297736
# 3         Swati  Gandhi            -3532.410                      0.500000
# 4          Sonal Somani              365.170                      0.400000
#
#    Prop_churn  prop_alive         t  Acquisition cost   Numerator      1+i  \
# 0     0.00795     0.99205  0.033333                 0  651.528838  1.99205
# 1     0.00924     0.99076  0.000000                 0  650.681630  1.99076
# 2     0.01411     0.98589  3.666667                 0  647.483258  1.98589
# 3     0.03802     0.96198  0.000000                 0  631.780365  1.96198
# 4     0.04787     0.95213  5.300000                 0  625.311378  1.95213
#
#       (1+i)t        CLTV
# 0   1.023238  636.732428
# 1   1.000000  650.681630
# 2  12.373779   52.327042
# 3   1.000000  631.780365
# 4  34.649446   18.046793

# %%
print (data.dtypes)
# Out:
# Name                             object
# Sum of Gross Margin             float64
# Sum of  Product Discounted %    float64
# Prop_churn                      float64
# prop_alive                      float64
# t                               float64
# Acquisition cost                  int64
# Numerator                       float64
# 1+i                             float64
# (1+i)t                          float64
# CLTV                            float64
# dtype: object

# %%
boxplot = data.boxplot( column = ['CLTV'])

# %%
data.describe()
# Out:
#        Sum of Gross Margin  Sum of  Product Discounted %    Prop_churn  \
# count         1.590800e+04                  15908.000000  15908.000000
# mean          1.329038e+03                      0.686909      0.837692
# std           8.381727e+04                     43.321339      0.071374
# min          -1.136642e+04                      0.000000      0.007950
# 25%           3.112000e+01                      0.000000      0.819950
# 50%           3.028350e+02                      0.000000      0.836200
# 75%           8.753500e+02                      0.500000      0.859753
# max           1.057117e+07                   5463.670371      1.000000
#
#          prop_alive             t  Acquisition cost     Numerator  \
# count  15908.000000  15908.000000           15908.0  15908.000000
# mean       0.162308      0.924487               0.0    106.595841
# std        0.071374      3.266961               0.0     46.875008
# min        0.000000      0.000000               0.0      0.000000
# 25%        0.140248      0.000000               0.0     92.107546
# 50%        0.163800      0.000000               0.0    107.575650
# 75%        0.180050      0.000000               0.0    118.247838
# max        0.992050     23.800000               0.0    651.528838
#
#                 1+i        (1+i)t          CLTV
# count  15908.000000  1.590800e+04  15908.000000
# mean       1.162308  1.230675e+02     95.000257
# std        0.071374  9.679641e+03     39.931452
# min        1.000000  1.000000e+00      0.000000
# 25%        1.140248  1.000000e+00     60.742807
# 50%        1.163800  1.000000e+00    105.227769
# 75%        1.180050  1.000000e+00    114.258081
# max        1.992050  1.183491e+06    650.681630

# %%
sns.boxplot(y='CLTV',data=data)
